# %% [markdown]
# **importing the packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(color_codes=True) 
import warnings
warnings.filterwarnings('ignore')

# %%
file_path="D:\\DEEP LEARNING\\ANN PROJECTS\\data sets\\customer churn prediction\\Churn_Modelling.csv"
churn_df=pd.read_csv(file_path)
churn_df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
churn_df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
churn_df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
churn_df.size
# Out:
# 140000

# %%
churn_df.shape
# Out:
# (10000, 14)

# %%
churn_df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
churn_df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
churn_df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# **we donot have any missing values  in the  dataset**

# %% [markdown]
# **seperation of categorical and numerical columns**

# %%
categorical_columns=[]
numerical_columns=[]
for i,j in churn_df.dtypes.items():
    if j=="O":
        categorical_columns+=[i]
    else:
        numerical_columns+=[i]
print("The categorical columns are :{}".format(categorical_columns))
print("The numerical  columns are : {}".format(numerical_columns))
# Out:
# The categorical columns are :['Surname', 'Geography', 'Gender']
# The numerical  columns are : ['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']

# %% [markdown]
# **EDA**

# %% [markdown]
# **working with the categorical columns**

# %%
categorical_columns
# Out:
# ['Surname', 'Geography', 'Gender']

# %% [markdown]
# - **surname which is unique for every person**
# - **so we will work on the Geography and Gender columns**

# %%
for index,i in enumerate(categorical_columns[1:]):
    data=churn_df[i].value_counts()
    my_data=dict(data)
    keys=list(my_data.keys())
    value=list(my_data.values())
    k=pd.DataFrame(zip(keys,value),columns=["keys","values"])
    plt.bar("keys","values",data=k)
    plt.show()

# %% [markdown]
# **working on numerical columns**

# %%
churn_df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
plt.figure(figsize=(15,15))
for index,i in enumerate(numerical_columns[2:]):   
    plt.subplot(3,3,index+1)
    plt.title(i)
    plt.hist(churn_df[i],bins=40)

# %%
plt.figure(figsize=(16,16))
for index,i in enumerate(numerical_columns[2:]):   
    plt.subplot(3,3,index+1)
    plt.title(i)
    plt.boxplot(churn_df[i],vert=False)

# %%
#histplots
num_cols=len(numerical_columns[2:])
num_rows=(num_cols)//3
fig, axs = plt.subplots(nrows=num_rows, ncols=3, figsize=(15, 5*num_rows))
axs = axs.flatten()
for i,j in enumerate(numerical_columns[2:]):
    sns.histplot(data=churn_df, x=j, 
                 hue='Exited', kde=True, ax=axs[i])
    axs[i].set_title(j)
fig.tight_layout()
plt.show()

# %%
churn_df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
sns.kdeplot(data=churn_df, x="Age", hue="Exited", multiple="stack")
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data=churn_df, x="CreditScore", hue="Exited", multiple="stack")
# Out:
# <Axes: xlabel='CreditScore', ylabel='Density'>

# %%
categorical_columns
# Out:
# ['Surname', 'Geography', 'Gender']

# %%
x=churn_df['Geography']
y=churn_df["Exited"]
data=pd.crosstab(x,y)
data.plot(kind="bar")
# Out:
# <Axes: xlabel='Geography'>

# %%
x=churn_df['Gender']
y=churn_df["Exited"]
data=pd.crosstab(x,y)
data.plot(kind="bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
x=churn_df['Gender']
z=churn_df['Geography']
y=churn_df["Exited"]
k=[x,z]
data=pd.crosstab(k,y)
data.plot(kind="bar")
# Out:
# <Axes: xlabel='Gender,Geography'>

# %% [markdown]
# **correlation**

# %%
corr_data=churn_df.corr(numeric_only=True)
corr_data
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.285323 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber       -0.009067       0.007246   0.000599        0.012044
# CustomerId      -0.012419       0.016972  -0.014025        0.001665
# CreditScore      0.006268       0.012238  -0.005458        0.025651
# Age              0.028308      -0.030680  -0.011721        0.085472
# Tenure          -0.012254       0.013444   0.022583       -0.028362
# Balance          1.000000      -0.304180  -0.014858       -0.010084
# NumOfProducts   -0.304180       1.000000   0.003183        0.009612
# HasCrCard       -0.014858       0.003183   1.000000       -0.011866
# IsActiveMember  -0.010084       0.009612  -0.011866        1.000000
# EstimatedSalary  0.012797       0.014204  -0.009933       -0.011421
# Exited           0.118533      -0.047820  -0.007138       -0.156128
#
#                  EstimatedSalary    Exited
# RowNumber              -0.005988 -0.016571
# CustomerId              0.015271 -0.006248
# CreditScore            -0.001384 -0.027094
# Age                    -0.007201  0.285323
# Tenure                  0.007784 -0.014001
# Balance                 0.012797  0.118533
# NumOfProducts           0.014204 -0.047820
# HasCrCard              -0.009933 -0.007138
# IsActiveMember         -0.011421 -0.156128
# EstimatedSalary         1.000000  0.012097
# Exited                  0.012097  1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr_data,annot=True)
# Out:
# <Axes: >

# %%
#converting the categorical columns into the numerical columns

# %%
#we have the three categorical columns we will convert them into  numerical columns

# %%
#surname
#actually surname we donot have any impact in the exited status 
#we can remove that column directly

# %%
#geogrpahy

# %%
churn_df["Geography"]
# Out:
# 0        France
# 1         Spain
# 2        France
# 3        France
# 4         Spain
#          ...
# 9995     France
# 9996     France
# 9997     France
# 9998    Germany
# 9999     France
# Name: Geography, Length: 10000, dtype: object

# %%
churn_df["Geography"].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
churn_df["Geography"].nunique()
# Out:
# 3

# %%
# we can use Label encoder here

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
churn_df["Geography"]=LE.fit_transform(churn_df["Geography"])

# %%
#Gender column

# %%
churn_df["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
churn_df["Gender"]=LE.fit_transform(churn_df["Gender"])

# %%
churn_df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619          0       0   42
# 1             2    15647311       Hill          608          2       0   41
# 2             3    15619304       Onio          502          0       0   42
# 3             4    15701354       Boni          699          0       0   39
# 4             5    15737888   Mitchell          850          2       0   43
# ...         ...         ...        ...          ...        ...     ...  ...
# 9995       9996    15606229   Obijiaku          771          0       1   39
# 9996       9997    15569892  Johnstone          516          0       1   35
# 9997       9998    15584532        Liu          709          0       0   36
# 9998       9999    15682355  Sabbatini          772          1       1   42
# 9999      10000    15628319     Walker          792          0       0   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# - **feature selction**
# - **we can directly remove**
# - **row number**
# - **customerid**
# - **surname**
# -**as they donot have any impact on the output or target column**

# %% [markdown]
# churn_df.columns

# %%
churn_df=churn_df.drop(["RowNumber","CustomerId",'Surname'],axis=1)
churn_df
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %% [markdown]
# **feature scaling**

# %%
list_1=[]
for i in churn_df.columns:
    list_1.append(i)
from sklearn.preprocessing import MinMaxScaler
for i in list_1:
    MMS=MinMaxScaler()
    churn_df[i]=MMS.fit_transform(churn_df[[i]])

# %%
churn_df
# Out:
#       CreditScore  Geography  Gender       Age  Tenure   Balance  \
# 0           0.538        0.0     0.0  0.324324     0.2  0.000000
# 1           0.516        1.0     0.0  0.310811     0.1  0.334031
# 2           0.304        0.0     0.0  0.324324     0.8  0.636357
# 3           0.698        0.0     0.0  0.283784     0.1  0.000000
# 4           1.000        1.0     0.0  0.337838     0.2  0.500246
# ...           ...        ...     ...       ...     ...       ...
# 9995        0.842        0.0     1.0  0.283784     0.5  0.000000
# 9996        0.332        0.0     1.0  0.229730     1.0  0.228657
# 9997        0.718        0.0     0.0  0.243243     0.7  0.000000
# 9998        0.844        0.5     1.0  0.324324     0.3  0.299226
# 9999        0.884        0.0     0.0  0.135135     0.4  0.518708
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          0.000000        1.0             1.0         0.506735     1.0
# 1          0.000000        0.0             1.0         0.562709     0.0
# 2          0.666667        1.0             0.0         0.569654     1.0
# 3          0.333333        0.0             0.0         0.469120     0.0
# 4          0.000000        1.0             1.0         0.395400     0.0
# ...             ...        ...             ...              ...     ...
# 9995       0.333333        1.0             0.0         0.481341     0.0
# 9996       0.000000        1.0             1.0         0.508490     0.0
# 9997       0.000000        0.0             1.0         0.210390     1.0
# 9998       0.333333        1.0             0.0         0.464429     1.0
# 9999       0.000000        1.0             0.0         0.190914     0.0
#
# [10000 rows x 11 columns]

# %% [markdown]
# **inorder to get faster convergence to the global minima and reduce the training time we will implement feature scaling**

# %%
X=churn_df.drop("Exited",axis=1)
y=churn_df["Exited"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1234)

# %% [markdown]
# **creating a neural network**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LeakyReLU,ReLU,Dropout
# Out:
# WARNING:tensorflow:From C:\Users\Venkatesh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model=Sequential()
# Out:
# WARNING:tensorflow:From C:\Users\Venkatesh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.add(Dense(units=10,activation='relu'))   # input layer

# %%
model.add(Dense(units=5,activation='relu'))  # hidden layer 1

# %%
model.add(Dense(units=4,activation='relu'))   # hideen layer 2

# %%
model.add(Dense(units=1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Venkatesh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# adding your learning rate
# tf.keras.optimizers.Adam(learning_rate=0.01)

# %%
history=model.fit(X_train,y_train,validation_split=0.33,batch_size=15,epochs=50)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Venkatesh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Venkatesh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 313/313 [==============================] - 4s 5ms/step - loss: 0.5917 - accuracy: 0.7520 - val_loss: 0.4980 - val_accuracy: 0.8023
# Epoch 2/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5066 - accuracy: 0.7919 - val_loss: 0.4873 - val_accuracy: 0.8023
# Epoch 3/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4936 - accuracy: 0.7919 - val_loss: 0.4730 - val_accuracy: 0.8023
# Epoch 4/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.4793 - accuracy: 0.7919 - val_loss: 0.4634 - val_accuracy: 0.8023
# Epoch 5/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.4666 - accuracy: 0.8002 - val_loss: 0.4526 - val_accuracy: 0.8105
# Epoch 6/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4560 - accuracy: 0.8087 - val_loss: 0.4457 - val_accuracy: 0.8148
# Epoch 7/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4472 - accuracy: 0.8089 - val_loss: 0.4414 - val_accuracy: 0.8170
# Epoch 8/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4427 - accuracy: 0.8145 - val_loss: 0.4374 - val_accuracy: 0.8183
# Epoch 9/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4373 - accuracy: 0.8162 - val_loss: 0.4319 - val_accuracy: 0.8161
# Epoch 10/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4345 - accuracy: 0.8157 - val_loss: 0.4287 - val_accuracy: 0.8217
# Epoch 11/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4314 - accuracy: 0.8172 - val_loss: 0.4242 - val_accuracy: 0.8230
# Epoch 12/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4274 - accuracy: 0.8243 - val_loss: 0.4210 - val_accuracy: 0.8252
# Epoch 13/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4238 - accuracy: 0.8228 - val_loss: 0.4172 - val_accuracy: 0.8269
# Epoch 14/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4206 - accuracy: 0.8230 - val_loss: 0.4154 - val_accuracy: 0.8269
# Epoch 15/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4152 - accuracy: 0.8268 - val_loss: 0.4182 - val_accuracy: 0.8217
# Epoch 16/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4149 - accuracy: 0.8268 - val_loss: 0.4103 - val_accuracy: 0.8304
# Epoch 17/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4104 - accuracy: 0.8296 - val_loss: 0.4072 - val_accuracy: 0.8312
# Epoch 18/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4068 - accuracy: 0.8349 - val_loss: 0.4091 - val_accuracy: 0.8299
# Epoch 19/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4042 - accuracy: 0.8302 - val_loss: 0.4021 - val_accuracy: 0.8334
# Epoch 20/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4018 - accuracy: 0.8354 - val_loss: 0.3995 - val_accuracy: 0.8334
# Epoch 21/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3994 - accuracy: 0.8337 - val_loss: 0.3967 - val_accuracy: 0.8330
# Epoch 22/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3969 - accuracy: 0.8358 - val_loss: 0.3934 - val_accuracy: 0.8338
# Epoch 23/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.3937 - accuracy: 0.8369 - val_loss: 0.3917 - val_accuracy: 0.8343
# Epoch 24/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3909 - accuracy: 0.8371 - val_loss: 0.3912 - val_accuracy: 0.8286
# Epoch 25/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3895 - accuracy: 0.8332 - val_loss: 0.3903 - val_accuracy: 0.8312
# Epoch 26/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3878 - accuracy: 0.8401 - val_loss: 0.3877 - val_accuracy: 0.8338
# Epoch 27/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3858 - accuracy: 0.8369 - val_loss: 0.3840 - val_accuracy: 0.8356
# Epoch 28/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3835 - accuracy: 0.8377 - val_loss: 0.3818 - val_accuracy: 0.8364
# Epoch 29/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3815 - accuracy: 0.8394 - val_loss: 0.3806 - val_accuracy: 0.8377
# Epoch 30/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3802 - accuracy: 0.8411 - val_loss: 0.3806 - val_accuracy: 0.8382
# Epoch 31/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3789 - accuracy: 0.8403 - val_loss: 0.3755 - val_accuracy: 0.8408
# Epoch 32/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3760 - accuracy: 0.8409 - val_loss: 0.3740 - val_accuracy: 0.8399
# Epoch 33/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.3755 - accuracy: 0.8422 - val_loss: 0.3791 - val_accuracy: 0.8343
# Epoch 34/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3748 - accuracy: 0.8413 - val_loss: 0.3716 - val_accuracy: 0.8408
# Epoch 35/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3738 - accuracy: 0.8428 - val_loss: 0.3718 - val_accuracy: 0.8395
# Epoch 36/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3715 - accuracy: 0.8437 - val_loss: 0.3688 - val_accuracy: 0.8403
# Epoch 37/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3697 - accuracy: 0.8439 - val_loss: 0.3684 - val_accuracy: 0.8412
# Epoch 38/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3687 - accuracy: 0.8426 - val_loss: 0.3682 - val_accuracy: 0.8416
# Epoch 39/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3682 - accuracy: 0.8467 - val_loss: 0.3658 - val_accuracy: 0.8434
# Epoch 40/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3670 - accuracy: 0.8456 - val_loss: 0.3636 - val_accuracy: 0.8438
# Epoch 41/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3671 - accuracy: 0.8454 - val_loss: 0.3626 - val_accuracy: 0.8451
# Epoch 42/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3662 - accuracy: 0.8445 - val_loss: 0.3660 - val_accuracy: 0.8442
# Epoch 43/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3645 - accuracy: 0.8467 - val_loss: 0.3618 - val_accuracy: 0.8464
# Epoch 44/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3632 - accuracy: 0.8467 - val_loss: 0.3630 - val_accuracy: 0.8451
# Epoch 45/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3626 - accuracy: 0.8477 - val_loss: 0.3608 - val_accuracy: 0.8442
# Epoch 46/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.3625 - accuracy: 0.8471 - val_loss: 0.3581 - val_accuracy: 0.8451
# Epoch 47/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3616 - accuracy: 0.8484 - val_loss: 0.3577 - val_accuracy: 0.8477
# Epoch 48/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.3608 - accuracy: 0.8469 - val_loss: 0.3627 - val_accuracy: 0.8429
# Epoch 49/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.3593 - accuracy: 0.8496 - val_loss: 0.3653 - val_accuracy: 0.8451
# Epoch 50/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3590 - accuracy: 0.8505 - val_loss: 0.3554 - val_accuracy: 0.8490

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                110
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dense_2 (Dense)             (None, 4)                 24
#
#  dense_3 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 194 (776.00 Byte)
# Trainable params: 194 (776.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("model accuracy")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model accuracy")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
y_pred=model.predict(X_test)
y_pred=y_pred>0.5
y_pred=np.where(y_pred,1,0)
# Out:
# 94/94 [==============================] - 0s 3ms/step

# %%
y_pred[:5]
# Out:
# array([[0],
#        [0],
#        [1],
#        [0],
#        [0]])

# %%
y_test[:5]
# Out:
# 2374    0.0
# 1784    0.0
# 6301    0.0
# 1600    0.0
# 7920    0.0
# Name: Exited, dtype: float64

# %%
len(y_test)
# Out:
# 3000

# %%
len(y_test)
# Out:
# 3000

# %% [markdown]
# **evaluation**

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
ac_s=accuracy_score(y_test,y_pred)
print("The accuracy",ac_s)
ps=precision_score(y_test,y_pred)
print("The precision",ps)
rs=recall_score(y_test,y_pred)
print("recall score",rs)
f1=f1_score(y_test,y_pred)
print("f1 score",f1)
# Out:
# The accuracy 0.8483333333333334
# The precision 0.7651245551601423
# recall score 0.35596026490066224
# f1 score 0.4858757062146893

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,roc_auc_score
cm=confusion_matrix(y_test,y_pred)
disp=ConfusionMatrixDisplay(confusion_matrix=cm,
                            display_labels = [False, True])
disp.plot()
plt.grid(False)
plt.show()


tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
print("True negative:",tn)
print("False postive:",fp)
print("False negative:",fn)
print("True postive:",tp)
# Out:
# True negative: 2330
# False postive: 66
# False negative: 389
# True postive: 215

# %%
model.get_weights()
# Out:
# [array([[ 1.87065199e-01,  4.54794288e-01, -1.61969677e-01,
#          -3.67183894e-01, -3.45759273e-01,  2.80607641e-01,
#           2.72930652e-01,  1.83975816e-01,  7.24541366e-01,
#           1.16908498e-01],
#         [-5.84853649e-01,  1.93774447e-01, -8.87499869e-01,
#           2.82055706e-01,  1.79525569e-01, -1.51848423e+00,
#          -1.53217152e-01, -1.57110378e-01,  5.27285278e-01,
#           2.03119919e-01],
#         [-1.86714575e-01, -5.48921376e-02, -2.72981673e-02,
#          -2.01176867e-01, -5.74072078e-02,  1.25836954e-01,
#           5.77895492e-02, -6.09164119e-01,  3.85820687e-01,
#          -9.39713269e-02],
#         [-3.46848845e-01, -1.09812033e+00,  2.46759742e-01,
#          -2.72515535e-01, -9.27776396e-01, -1.06292403e+00,
#          -8.35987702e-02, -4.30159755e-02,  1.22613437e-01,
#           1.14266825e+00],
#         [-2.99306214e-01, -1.64268926e-01, -4.39708024e-01,
#           3.87265444e-01,  5.21468341e-01,  2.27156818e-01,
#           1.40387341e-01,  1.19231082e-01,  2.91374773e-01,
#           2.03295052e-02],
#         [ 5.85526228e-01, -4.58112545e-02, -4.89719898e-01,
#           1.96034029e-01,  1.43393666e-01,  1.64527789e-01,
#          -4.74928826e-01,  9.49674994e-02, -1.54985353e-01,
#           6.47864103e-01],
#         [-1.38655424e-01, -3.41448307e-01, -3.44340086e-01,
#          -3.07705909e-01, -3.37325066e-01, -6.70560181e-01,
#          -3.19445443e+00, -1.40474781e-01, -7.28565156e-01,
#           1.27944934e+00],
#         [-1.49613827e-01, -1.89501286e-01,  6.05181813e-01,
#           3.40787977e-01, -2.36030981e-01,  6.03395933e-03,
#           8.65947083e-02, -1.60767138e-01,  2.96884209e-01,
#          -3.43159586e-02],
#         [-1.09517142e-01,  5.54378271e-01, -5.63258901e-02,
#           1.27996409e+00, -5.08025736e-02, -1.87551737e-01,
#          -3.01701128e-02, -4.73748326e-01,  1.84890434e-01,
#          -8.04947019e-02],
#         [ 3.00089300e-01,  1.10563904e-01, -2.91140556e-01,
#           4.14777361e-03,  1.82702079e-01, -2.71232589e-03,
#           2.37952799e-01,  6.52312636e-01,  9.99377444e-02,
#           5.77408448e-03]], dtype=float32),
#  array([ 0.3514577 ,  0.58090067,  0.11887167,  0.05079984,  0.24570869,
#          0.2838676 ,  0.5198705 , -0.30184168,  0.32117078, -0.05881574],
#        dtype=float32),
#  array([[-0.08507967, -0.60330534, -0.68794125,  0.19655704, -0.44238776],
#         [ 0.36279604, -0.8982689 ,  0.43288225,  0.48664045, -0.4423843 ],
#         [ 0.59095997,  0.28848836, -0.18288653, -0.03061191,  0.4219224 ],
#         [-0.2536704 , -0.97451556,  0.03599221,  0.33404848, -0.589781  ],
#         [ 0.84531397,  0.10581717, -0.08971802,  0.09581649, -0.24731773],
#         [ 0.20361404, -0.03007859, -0.8841875 ,  0.83658403, -0.148516  ],
#         [-0.86902237,  0.7152227 ,  0.81881696, -1.007414  , -0.47968516],
#         [-0.304222  ,  0.76459783, -0.6595649 , -0.2538474 ,  0.03865343],
#         [ 0.01537334, -0.04461968, -0.36815134,  0.59408426, -0.61487395],
#         [-0.24361736,  0.80255365,  0.72394425, -0.64762276, -0.07803309]],
#        dtype=float32),
#  array([ 0.51989913, -0.12952037,  0.10504907,  0.4368508 ,  0.        ],
#        dtype=float32),
#  array([[-0.20113814,  1.7221619 ,  0.2052108 , -0.91791105],
#         [ 0.8834372 , -0.47250348,  0.02932807,  1.6191458 ],
#         [ 0.31279176, -0.54178655, -0.49700364,  1.1007876 ],
#         [-0.8543448 ,  1.3067789 , -0.4474108 ,  0.0995775 ],
#         [ 0.54285884,  0.01278192,  0.3437338 ,  0.55306196]],
#        dtype=float32),
#  array([ 0.22172631,  0.37320417, -0.02064876, -0.1049336 ], dtype=float32),
#  array([[ 1.3354077],
#         [-1.0460382],
#         [ 1.0496519],
#         [ 1.2373353]], dtype=float32),
#  array([-0.31634605], dtype=float32)]
